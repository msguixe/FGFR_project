# %% [markdown]
# # Kallisto Quantification Analysis

# %%
import pandas as pd
import os

# %% [markdown]
# ### Get abundances

# %%
#Get files with abundance
samples = os.listdir('../output/')
df = pd.DataFrame()
for sample in samples:
    try:
        df1 = pd.read_csv('../output/'+sample+'/abundance.tsv',sep='\t')
        df1['sample'] = sample
        df = pd.concat([df,df1],ignore_index=True)
    except:
        next
df
# Out:
#                 target_id  length  eff_length  est_counts       tpm  sample
# 0       ENST00000631435.1      12     13.0000         0.0  0.000000  PDX156
# 1       ENST00000434970.2       9     10.0000         0.0  0.000000  PDX156
# 2       ENST00000448914.1      13     14.0000         0.0  0.000000  PDX156
# 3       ENST00000415118.1       8      9.0000         0.0  0.000000  PDX156
# 4       ENST00000632684.1      12     13.0000         0.0  0.000000  PDX156
# ...                   ...     ...         ...         ...       ...     ...
# 755007  ENST00000639790.1    1370   1229.3200         0.0  0.000000  PDX296
# 755008  ENST00000639660.1     284    153.3090         0.0  0.000000  PDX296
# 755009  ENST00000643577.1     105     25.4309         0.0  0.000000  PDX296
# 755010  ENST00000646356.1     900    759.3210         0.0  0.000000  PDX296
# 755011  ENST00000645792.1     930    789.3210         0.5  0.060023  PDX296
#
# [755012 rows x 6 columns]

# %%
len(df.groupby('sample').count()) # abundances from all 5 samples
# Out:
# 4

# %% [markdown]
# ### Get gene names

# %%
annot_df = pd.read_csv('data/ens_transcript_symbol.tsv',sep='\t')
annot_df
# Out:
#        Transcript stable ID Transcript stable ID version   Gene name
# 0           ENST00000387314            ENST00000387314.1       MT-TF
# 1           ENST00000389680            ENST00000389680.2     MT-RNR1
# 2           ENST00000387342            ENST00000387342.1       MT-TV
# 3           ENST00000387347            ENST00000387347.2     MT-RNR2
# 4           ENST00000386347            ENST00000386347.1      MT-TL1
# ...                     ...                          ...         ...
# 256178      ENST00000355360            ENST00000355360.8       PGBD2
# 256179      ENST00000329291            ENST00000329291.6       PGBD2
# 256180      ENST00000462488            ENST00000462488.1       PGBD2
# 256181      ENST00000363625            ENST00000363625.1  RNU6-1205P
# 256182      ENST00000430973            ENST00000430973.1   RPL23AP25
#
# [256183 rows x 3 columns]

# %%
# annot_df = annot_df.rename(columns={'Transcript stable ID':'target_id'})
df['Transcript stable ID'] = df['target_id'].str.split('.',expand=True)[0]
df = pd.merge(df,annot_df,how='left')
df
# Out:
#                 target_id  length  eff_length  est_counts       tpm  sample  \
# 0       ENST00000631435.1      12     13.0000         0.0  0.000000  PDX156
# 1       ENST00000434970.2       9     10.0000         0.0  0.000000  PDX156
# 2       ENST00000448914.1      13     14.0000         0.0  0.000000  PDX156
# 3       ENST00000415118.1       8      9.0000         0.0  0.000000  PDX156
# 4       ENST00000632684.1      12     13.0000         0.0  0.000000  PDX156
# ...                   ...     ...         ...         ...       ...     ...
# 755007  ENST00000639790.1    1370   1229.3200         0.0  0.000000  PDX296
# 755008  ENST00000639660.1     284    153.3090         0.0  0.000000  PDX296
# 755009  ENST00000643577.1     105     25.4309         0.0  0.000000  PDX296
# 755010  ENST00000646356.1     900    759.3210         0.0  0.000000  PDX296
# 755011  ENST00000645792.1     930    789.3210         0.5  0.060023  PDX296
#
#        Transcript stable ID Transcript stable ID version    Gene name
# 0           ENST00000631435            ENST00000631435.1        TRBD1
# 1           ENST00000434970            ENST00000434970.2        TRDD2
# 2           ENST00000448914            ENST00000448914.1        TRDD3
# 3           ENST00000415118            ENST00000415118.1        TRDD1
# 4           ENST00000632684            ENST00000632684.1        TRBD1
# ...                     ...                          ...          ...
# 755007      ENST00000639790            ENST00000639790.1       LILRP1
# 755008      ENST00000639660            ENST00000639660.1  AC245128.19
# 755009      ENST00000643577                          NaN          NaN
# 755010      ENST00000646356                          NaN          NaN
# 755011      ENST00000645792            ENST00000645792.2       OR2A12
#
# [755012 rows x 9 columns]

# %%
ids_not_found = df['Transcript stable ID'][df['Gene name'].isnull()].tolist()
ids_not_found = [ids.split('.')[0] for ids in ids_not_found]
len(ids_not_found)
# Out:
# 8420

# %% [markdown]
# ### Get sample names

# %%
fgfrs = ['FGFR1','FGFR2','FGFR3','FGFR4']

# %%
df
# Out:
#                 target_id  length  eff_length  est_counts       tpm  sample  \
# 0       ENST00000631435.1      12     13.0000         0.0  0.000000  PDX156
# 1       ENST00000434970.2       9     10.0000         0.0  0.000000  PDX156
# 2       ENST00000448914.1      13     14.0000         0.0  0.000000  PDX156
# 3       ENST00000415118.1       8      9.0000         0.0  0.000000  PDX156
# 4       ENST00000632684.1      12     13.0000         0.0  0.000000  PDX156
# ...                   ...     ...         ...         ...       ...     ...
# 755007  ENST00000639790.1    1370   1229.3200         0.0  0.000000  PDX296
# 755008  ENST00000639660.1     284    153.3090         0.0  0.000000  PDX296
# 755009  ENST00000643577.1     105     25.4309         0.0  0.000000  PDX296
# 755010  ENST00000646356.1     900    759.3210         0.0  0.000000  PDX296
# 755011  ENST00000645792.1     930    789.3210         0.5  0.060023  PDX296
#
#        Transcript stable ID Transcript stable ID version    Gene name
# 0           ENST00000631435            ENST00000631435.1        TRBD1
# 1           ENST00000434970            ENST00000434970.2        TRDD2
# 2           ENST00000448914            ENST00000448914.1        TRDD3
# 3           ENST00000415118            ENST00000415118.1        TRDD1
# 4           ENST00000632684            ENST00000632684.1        TRBD1
# ...                     ...                          ...          ...
# 755007      ENST00000639790            ENST00000639790.1       LILRP1
# 755008      ENST00000639660            ENST00000639660.1  AC245128.19
# 755009      ENST00000643577                          NaN          NaN
# 755010      ENST00000646356                          NaN          NaN
# 755011      ENST00000645792            ENST00000645792.2       OR2A12
#
# [755012 rows x 9 columns]

# %%
#PDX156
df[['Gene name','est_counts','tpm']][(df['sample']=='PDX156')&(df['Gene name'].isin(fgfrs))].groupby('Gene name').max()
# Out:
#            est_counts        tpm
# Gene name
# FGFR1       1708.3400  28.439300
# FGFR2        552.3910   6.869560
# FGFR3         44.4833   0.486627
# FGFR4        107.2660   1.801080

# %%
#PDX288
df[['Gene name','est_counts','tpm']][(df['sample']=='PDX288')&(df['Gene name'].isin(fgfrs))].groupby('Gene name').max()
# Out:
#            est_counts      tpm
# Gene name
# FGFR1         35.6846  2.55152
# FGFR2         53.3375  1.42005
# FGFR3        166.5230  3.91074
# FGFR4         19.0771  1.16907

# %%
#PDX296
df[['Gene name','est_counts','tpm']][(df['sample']=='PDX296')&(df['Gene name'].isin(fgfrs))].groupby('Gene name').max()
# Out:
#            est_counts        tpm
# Gene name
# FGFR1        577.0100  36.632200
# FGFR2         19.3420   0.640747
# FGFR3         14.6114   0.552087
# FGFR4         27.0415   1.339370

# %%
#PDX
df[['Gene name','est_counts','tpm']][(df['sample']=='PDX296')&(df['Gene name'].isin(fgfrs))].groupby('Gene name').max()
# Out:
#            est_counts        tpm
# Gene name
# FGFR1        577.0100  36.632200
# FGFR2         19.3420   0.640747
# FGFR3         14.6114   0.552087
# FGFR4         27.0415   1.339370

# %% [markdown]
# ### Check FGFR1,2,3,4 accross samples

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fgfr_df = df[['sample','Gene name','tpm']][df['Gene name'].isin(fgfrs)].groupby(['sample','Gene name'],as_index=False).max()
samples = fgfr_df['sample'].tolist()
samples = list(set(samples))
matrix_fgfr_df = pd.DataFrame({'Gene name':['FGFR1','FGFR2','FGFR3','FGFR4']})
for sample in samples:
    sample_df = fgfr_df[fgfr_df['sample']==sample]
    sample_df = sample_df.rename(columns={'tpm':sample})
    sample_df.drop(columns='sample',inplace=True)
    sample_df = sample_df[['Gene name',sample]]
    matrix_fgfr_df = pd.merge(matrix_fgfr_df,sample_df,how='left')
matrix_fgfr_df = matrix_fgfr_df.set_index('Gene name')
matrix_fgfr_df
# Out:
#               PDX313  PDX244LR     PDX343      PDX191      251  PDX244LR1  \
# Gene name
# FGFR1      16.613600  15.02120  16.766300    7.310530  3.81697   15.02120
# FGFR2       0.299202   1.30431   0.683092    0.870678  1.78241    1.30431
# FGFR3       0.920502   5.00334   7.202580  131.532000  7.44018    5.00334
# FGFR4       4.270120   2.27329   5.448490    4.591150  7.76403    2.27329
#
#            173JAL_CNTL     PDX153   98_CNTL  PDX284JAL  ...  PDX153_CNTL  \
# Gene name                                               ...
# FGFR1         15.21600   8.986380  4.491750    29.4647  ...     8.986380
# FGFR2          1.51324   0.434092  9.327970    57.5493  ...     0.434092
# FGFR3          9.10814   5.033210  0.300336    49.5847  ...     5.033210
# FGFR4          7.57646  64.909900  3.627520     8.2666  ...    64.909900
#
#             JAL347    PDX287  PDX131_CNTL     PDX244    PDX319   PDX329  \
# Gene name
# FGFR1      6.60995   3.33318    42.500700  12.144500   5.00717  6.97922
# FGFR2      2.21085  21.65280     0.057689   0.786329   7.67979  7.30742
# FGFR3      3.17578   7.74127    15.795500   5.228390  16.47970  5.41022
# FGFR4      2.05210   1.06909     5.169650   1.529580   4.29415  1.58217
#
#            118JAL_CNTL     251JAL       293
# Gene name
# FGFR1         7.603710   9.492790   6.33128
# FGFR2         0.116147   0.133644  13.06500
# FGFR3        14.909600   4.502910   7.34244
# FGFR4        14.126800  12.546700   2.94195
#
# [4 rows x 23 columns]

# %%
samples
# Out:
# ['PDX313',
#  'PDX244LR',
#  'PDX343',
#  'PDX191',
#  '251',
#  'PDX244LR1',
#  '173JAL_CNTL',
#  'PDX153',
#  '98_CNTL',
#  'PDX284JAL',
#  'PDX225',
#  'PDX222',
#  'PDX39_1R',
#  'PDX153_CNTL',
#  'JAL347',
#  'PDX287',
#  'PDX131_CNTL',
#  'PDX244',
#  'PDX319',
#  'PDX329',
#  '118JAL_CNTL',
#  '251JAL',
#  '293']

# %%
#sort samples by response
samples_by_resp = ['PDX39','PDX343','PDX225','PDX131_CNTL','251','PDX153','PDX222','293','PDX191']

# %%
len(samples_by_resp)
# Out:
# 9

# %%
data = fgfr_df[fgfr_df['Gene name']=='FGFR2']
x = data['sample']
y = data['tpm']
s = samples_by_resp
g = sns.barplot(x=x,y=y,data=data,order=s,color='green')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title('FGFR2',size=20)
# Out:
# Text(0.5, 1.0, 'FGFR2')

# %%
data = fgfr_df[fgfr_df['Gene name']=='FGFR1']
x = data['sample']
y = data['tpm']
s = samples_by_resp
g = sns.barplot(x=x,y=y,data=data,order=s,color='black')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title('FGFR1',size=20)
# Out:
# Text(0.5, 1.0, 'FGFR1')

# %%
data = fgfr_df[fgfr_df['Gene name']=='FGFR3']
x = data['sample']
y = data['tpm']
s = samples_by_resp
g = sns.barplot(x=x,y=y,data=data,order=s,color='purple')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title('FGFR3',size=20)
# Out:
# Text(0.5, 1.0, 'FGFR3')

# %%
data = fgfr_df[fgfr_df['Gene name']=='FGFR4']
x = data['sample']
y = data['tpm']
s = samples_by_resp
g = sns.barplot(x=x,y=y,data=data,order=s,color='orange')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title('FGFR4',size=20)
# Out:
# Text(0.5, 1.0, 'FGFR4')

# %%
def heatmap (matrix,x=2,y=8,cmap='Reds',norm=False):
    
    matrix = matrix.reindex(columns=samples_by_resp)
    
    if norm == True:
        matrix = matrix.div(matrix.max(axis=1), axis=0)
    plt.figure(figsize=(x,y))
    sns.heatmap(matrix,cmap=cmap,linewidths=1,linecolor='white')
    
    plt.text(x=2,y=-1,s='NON-RESP')
    plt.text(x=6,y=-1,s='RESP')
    plt.text(x=0,y=-0.7,s='_______________________________________________')
    plt.text(x=4.1,y=-0.7,s='_________________________________________________________')

# %%
heatmap(matrix_fgfr_df,x=12,y=1,norm=True) #normalised colors by row (gene)

# %%
heatmap(matrix_fgfr_df,x=12,y=1) #not normalized

# %%
fgfs = ['FGF1','FGF2','FGF3','FGF4','FGF5','FGF6','FGF7','FGF8','FGF9','FGF10',
        'FGF16','FGF17','FGF18','FGF19','FGF20','FGF21','FGF22','FGF23']
#PDX325
fgfr_df = df[['sample','Gene name','tpm']][df['Gene name'].isin(fgfs)].groupby(['sample','Gene name'],as_index=False).max()
samples = fgfr_df['sample'].tolist()
samples = list(set(samples))
matrix_df = pd.DataFrame({'Gene name':fgfs})
for sample in samples:
    sample1_df = fgfr_df[fgfr_df['sample']==sample]
    sample1_df = sample1_df.rename(columns={'tpm':sample})
    sample1_df.drop(columns='sample',inplace=True)
    sample1_df = sample1_df[['Gene name',sample]]
    matrix_df = pd.merge(matrix_df,sample1_df,how='left')
matrix_df = matrix_df.set_index('Gene name')
heatmap(matrix_df,x=12,y=5) #not normalized

# %%
heatmap(matrix_df,x=12,y=5,norm=True) #not normalized

# %% [markdown]
# ### Check all counts (quality of the sample)

# %%
all_counts_df = df.groupby('sample',as_index=False).sum()
all_counts_df[['tpm']]
g = sns.barplot(x=all_counts_df['sample'],y=all_counts_df['est_counts'])
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '118JAL_CNTL'),
#  Text(1, 0, '173JAL_CNTL'),
#  Text(2, 0, '251'),
#  Text(3, 0, '251JAL'),
#  Text(4, 0, '293'),
#  Text(5, 0, '98_CNTL'),
#  Text(6, 0, 'JAL347'),
#  Text(7, 0, 'PDX131_CNTL'),
#  Text(8, 0, 'PDX153'),
#  Text(9, 0, 'PDX153_CNTL'),
#  Text(10, 0, 'PDX191'),
#  Text(11, 0, 'PDX222'),
#  Text(12, 0, 'PDX225'),
#  Text(13, 0, 'PDX244'),
#  Text(14, 0, 'PDX244LR'),
#  Text(15, 0, 'PDX244LR1'),
#  Text(16, 0, 'PDX284JAL'),
#  Text(17, 0, 'PDX287'),
#  Text(18, 0, 'PDX313'),
#  Text(19, 0, 'PDX319'),
#  Text(20, 0, 'PDX329'),
#  Text(21, 0, 'PDX343'),
#  Text(22, 0, 'PDX39_1R')]

# %% [markdown]
# ## TF analysis

# %%
gh_df = pd.read_excel('data/GeneHancer_version_4-4.xlsx')
gh_df
# Out:
#         chrom      source feature name      start        end  score strand  \
# 0        chr2  GeneHancer     Enhancer   70017801   70018000   0.52      .
# 1       chr18  GeneHancer     Enhancer   48592690   48592839   0.96      .
# 2        chr5  GeneHancer     Enhancer  168312357  168319217   1.77      .
# 3       chr12  GeneHancer     Enhancer   47204578   47219611   1.28      .
# 4       chr21  GeneHancer     Enhancer   39630072   39635066   1.29      .
# ...       ...         ...          ...        ...        ...    ...    ...
# 218112  chr10  GeneHancer     Enhancer   44334083   44335821   0.71      .
# 218113   chr9  GeneHancer     Enhancer   80873797   80874459   0.25      .
# 218114   chr9  GeneHancer     Enhancer   98305468   98307965   0.59      .
# 218115  chr20  GeneHancer     Enhancer    5602988    5606828   0.65      .
# 218116  chr10  GeneHancer     Enhancer   48648321   48648657   0.27      .
#
#        frame                                         attributes
# 0          .  genehancer_id=GH02F070017;connected_gene=PCBP1...
# 1          .  genehancer_id=GH18F048592;connected_gene=ENSG0...
# 2          .  genehancer_id=GH05F168312;connected_gene=WWC1;...
# 3          .  genehancer_id=GH12F047204;connected_gene=RPAP3...
# 4          .  genehancer_id=GH21F039630;connected_gene=B3GAL...
# ...      ...                                                ...
# 218112     .  genehancer_id=GH10F044334;connected_gene=LOC10...
# 218113     .  genehancer_id=GH09F080873;connected_gene=LOC10...
# 218114     .  genehancer_id=GH09F098305;connected_gene=TBC1D...
# 218115     .  genehancer_id=GH20F005602;connected_gene=LOC64...
# 218116     .  genehancer_id=GH10F048648;connected_gene=ARHGA...
#
# [218117 rows x 9 columns]

# %%
attributes = gh_df['attributes'].tolist()
attributes[0]
# Out:
# 'genehancer_id=GH02F070017;connected_gene=PCBP1-AS1;score=12.90;connected_gene=ASPRV1;score=11.69;connected_gene=PIR47967;score=0.29;connected_gene=RN7SL470P;score=0.20'

# %%
gh_df['gh_id'] = gh_df['attributes'].str.split(';',expand=True)[0].str.split('=',expand=True)[1]
gh_df['gene'] = gh_df['attributes'].str.split(';',expand=True)[1].str.split('=',expand=True)[1]
gh_df = gh_df[['gh_id','gene','score']]
gh_df
# Out:
#               gh_id             gene  score
# 0       GH02F070017        PCBP1-AS1   0.52
# 1       GH18F048592  ENSG00000278983   0.96
# 2       GH05F168312             WWC1   1.77
# 3       GH12F047204            RPAP3   1.28
# 4       GH21F039630      B3GALT5-AS1   1.29
# ...             ...              ...    ...
# 218112  GH10F044334     LOC101929465   0.71
# 218113  GH09F080873     LOC105376105   0.25
# 218114  GH09F098305           TBC1D2   0.59
# 218115  GH20F005602        LOC643406   0.65
# 218116  GH10F048648         ARHGAP22   0.27
#
# [218117 rows x 3 columns]

# %%
gh_df[gh_df['gene']=='FGFR2']
# Out:
#               gh_id   gene  score
# 3984    GH10F121528  FGFR2   0.52
# 7614    GH10F121157  FGFR2   1.29
# 33936   GH10F121459  FGFR2   1.35
# 37367   GH10F121595  FGFR2   0.56
# 37442   GH10F121574  FGFR2   0.25
# 55785   GH10F121535  FGFR2   0.25
# 60386   GH10F121509  FGFR2   0.32
# 82035   GH10F121526  FGFR2   0.25
# 92318   GH10F121540  FGFR2   0.46
# 98147   GH10F121527  FGFR2   0.38
# 111041  GH10F121593  FGFR2   0.52
# 112490  GH10F121529  FGFR2   0.25
# 113440  GH10F121522  FGFR2   1.61
# 133550  GH10F121531  FGFR2   0.25
# 133607  GH10F121554  FGFR2   0.56
# 134093  GH10F121406  FGFR2   0.59
# 145620  GH10F121553  FGFR2   1.07
# 155240  GH10F121512  FGFR2   0.59
# 175952  GH10F121514  FGFR2   0.62
# 178141  GH10F121455  FGFR2   0.81
# 193006  GH10F121525  FGFR2   0.38
# 207755  GH10F121495  FGFR2   0.84

# %%
gh_df[gh_df['gene']=='FGFR3']
# Out:
#               gh_id   gene  score
# 66206   GH04F001970  FGFR3   0.62
# 85041   GH04F001792  FGFR3   0.97
# 183323  GH04F001785  FGFR3   0.25
# 211825  GH04F001784  FGFR3   0.46

# %%
with open('data/tf_FGFR2.txt') as f:
    tf_fgfr2 = f.read().splitlines()
tf_fgfr2
# Out:
# ['HNRNPL',
#  'TEAD4',
#  'PRDM10',
#  'ZNF629',
#  'RFX1',
#  'KDM1A',
#  'ZNF692',
#  'PRDM1',
#  'ZIC2',
#  'ZSCAN4',
#  'PATZ1',
#  'CTCF',
#  'ZNF501',
#  'POLR2A',
#  'ZNF600',
#  'ZNF341',
#  'ZNF37A',
#  'ZFX',
#  'CEBPA',
#  'ZNF561',
#  'ARNT',
#  'NONO',
#  'KLF9',
#  'ZBTB20',
#  'SP2',
#  'RAD21',
#  'ZNF524',
#  'ZXDB',
#  'CTBP1',
#  'ZBTB10',
#  'BMI1',
#  'RNF2',
#  'ZNF580',
#  'BCL11A',
#  'ZBTB48',
#  'ZBTB26',
#  'ZBTB17',
#  'YY1',
#  'SCRT1',
#  'TFDP1',
#  'FOXM1',
#  'ZFHX2',
#  'KLF8',
#  'ZNF777',
#  'ZNF189',
#  'ELF1',
#  'ZNF335',
#  'ZNF610',
#  'GABPB1',
#  'ZFP69B',
#  'ETS1',
#  'SKIL',
#  'KLF17',
#  'ZNF768',
#  'HIC1',
#  'ZSCAN5A',
#  'SIN3A',
#  'CEBPB',
#  'SMAD4',
#  'BCL6',
#  'PAX8',
#  'ZNF366',
#  'VEZF1',
#  'NRF1',
#  'ZNF324',
#  'MAFK',
#  'ZNF660',
#  'GLIS1',
#  'TRIM28',
#  'ZNF398',
#  'ZNF2',
#  'ZNF143',
#  'KLF10',
#  'KLF16',
#  'SP3',
#  'ZMYM3',
#  'TAF1',
#  'NANOG',
#  'GTF2F1',
#  'TBP',
#  'RB1',
#  'NFYC',
#  'EGR2',
#  'L3MBTL2',
#  'RBPJ',
#  'SP1',
#  'ZNF362',
#  'ELF3',
#  'POU5F1',
#  'EGR1',
#  'CEBPG',
#  'MZF1',
#  'SP7',
#  'ZBTB7A',
#  'JUND',
#  'EZH2',
#  'GLIS2',
#  'ZBTB8A',
#  'PKNOX1',
#  'ZEB2']

# %%
fgfr_df = df[['sample','Gene name','tpm']][df['Gene name'].isin(tf_fgfr2)].groupby(['sample','Gene name'],as_index=False).max()
samples = fgfr_df['sample'].tolist()
samples = list(set(samples))
matrix_df = pd.DataFrame({'Gene name':tf_fgfr2})
for sample in samples:
    sample1_df = fgfr_df[fgfr_df['sample']==sample]
    sample1_df = sample1_df.rename(columns={'tpm':sample})
    sample1_df.drop(columns='sample',inplace=True)
    sample1_df = sample1_df[['Gene name',sample]]
    matrix_df = pd.merge(matrix_df,sample1_df,how='left')
matrix_df = matrix_df.set_index('Gene name')
heatmap(matrix_df,x=12,y=20) #not normalized

# %%
heatmap(matrix_df,x=12,y=20,norm=True) #not normalized

# %%
with open('data/tf_FGFR3.txt') as f:
    tf_fgfr3 = f.read().splitlines()
tf_fgfr3
# Out:
# ['HNRNPL',
#  'GATAD2A',
#  'TEAD4',
#  'SOX13',
#  'KDM1A',
#  'FOXA1',
#  'MTA2',
#  'ZIC2',
#  'RBFOX2',
#  'RXRB',
#  'PATZ1',
#  'IRF2',
#  'SP1',
#  'POLR2A',
#  'EZH2',
#  'GABPA',
#  'ZNF37A',
#  'ZFX',
#  'GATAD2B',
#  'CEBPA',
#  'ZNF561',
#  'SCRT2',
#  'ARNT',
#  'RFX3',
#  'NONO',
#  'ZBTB20',
#  'ETS1',
#  'SP2',
#  'TCF7',
#  'UBTF',
#  'EGR1',
#  'CTBP1',
#  'ZBTB26',
#  'ZBTB2',
#  'ZKSCAN8',
#  'TGIF2',
#  'U2AF2',
#  'BCL11A',
#  'KAT7',
#  'ZBTB48',
#  'YY1',
#  'KLF4',
#  'CHD2',
#  'EP300',
#  'MAX',
#  'ZBTB25',
#  'MYC',
#  'ZNF205',
#  'TEAD1',
#  'ZNF423',
#  'RBM22',
#  'TARDBP',
#  'TFDP1',
#  'KDM6A',
#  'PCBP1',
#  'CREM',
#  'NR2F2',
#  'MBD2',
#  'KLF9',
#  'FOXM1',
#  'ZFHX2',
#  'KLF8',
#  'HNRNPH1',
#  'ZNF792',
#  'SAP130',
#  'TBP',
#  'ZNF335',
#  'MIER3',
#  'GABPB1',
#  'KLF6',
#  'ZGPAT',
#  'ZNF384',
#  'ZFP69B',
#  'SAFB',
#  'GATAD1',
#  'DRAP1',
#  'FOSL2',
#  'HIC1',
#  'SIN3B',
#  'SMAD5',
#  'SMAD4',
#  'CEBPB',
#  'BCL6',
#  'TFAP4',
#  'HNF4A',
#  'SIN3A',
#  'CHD4',
#  'VEZF1',
#  'ZFP64',
#  'NFIL3',
#  'BCL11B',
#  'IKZF5',
#  'PAF1',
#  'RXRA',
#  'NRF1',
#  'THAP11',
#  'ZNF3',
#  'RARA',
#  'NFIA',
#  'DMAP1',
#  'GLIS1',
#  'THRB',
#  'MBD1',
#  'ZNF398',
#  'ARID4B',
#  'ETV4',
#  'ZBTB33',
#  'TEAD3',
#  'HMG20A',
#  'NR2F6',
#  'KDM3A',
#  'KLF16',
#  'XRCC5',
#  'SMARCA4',
#  'RFX1',
#  'SP3',
#  'ZNF48',
#  'KLF1',
#  'MIER2',
#  'REST',
#  'MXI1',
#  'HNF4G',
#  'NR2F1',
#  'SOX5',
#  'GTF2F1',
#  'LCORL',
#  'ARID3A',
#  'ZHX2',
#  'ZNF580',
#  'RB1',
#  'L3MBTL2',
#  'RBPJ',
#  'GATA4',
#  'ELF3',
#  'FOXA3',
#  'MLX',
#  'SMC3',
#  'CEBPG',
#  'MIXL1',
#  'ZNF652',
#  'PPARG',
#  'MLLT1',
#  'HMG20B',
#  'SP7',
#  'ZBTB7A',
#  'ZNF644',
#  'HDAC1',
#  'HNF1A',
#  'GLIS2',
#  'SP5',
#  'ZNF639',
#  'CTCF',
#  'ZBTB8A',
#  'ERF',
#  'MNT',
#  'GMEB1',
#  'KAT8',
#  'RERE',
#  'AHR']

# %%
fgfr_df = df[['sample','Gene name','tpm']][df['Gene name'].isin(tf_fgfr3)].groupby(['sample','Gene name'],as_index=False).max()
samples = fgfr_df['sample'].tolist()
samples = list(set(samples))
matrix_df = pd.DataFrame({'Gene name':tf_fgfr3})
for sample in samples:
    sample1_df = fgfr_df[fgfr_df['sample']==sample]
    sample1_df = sample1_df.rename(columns={'tpm':sample})
    sample1_df.drop(columns='sample',inplace=True)
    sample1_df = sample1_df[['Gene name',sample]]
    matrix_df = pd.merge(matrix_df,sample1_df,how='left')
matrix_df = matrix_df.set_index('Gene name')
heatmap(matrix_df,x=12,y=30) #not normalized

# %%
heatmap(matrix_df,x=12,y=30,norm=True) #not normalized

# %%
fgfr_df = df[['sample','Gene name','tpm']][df['Gene name'].isin(fgfrs)].groupby(['sample','Gene name'],as_index=False).max()

data = fgfr_df[fgfr_df['Gene name']=='FGFR3']
x = data['sample']
y = data['tpm']
s = samples_by_resp
g = sns.barplot(x=x,y=y,data=data,order=s,color='purple')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title('FGFR3',size=20)
# Out:
# Text(0.5, 1.0, 'FGFR3')

# %%
max_df = df[['sample','Gene name','tpm']].groupby(['sample','Gene name'],as_index=False).max()

data = max_df[max_df['Gene name']=='TEAD1']
x = data['sample']
y = data['tpm']
s = samples_by_resp
g = sns.barplot(x=x,y=y,data=data,order=s,color='grey')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title('TEAD1',size=20)
# Out:
# Text(0.5, 1.0, 'TEAD1')

# %%
max_df = df[['sample','Gene name','tpm']].groupby(['sample','Gene name'],as_index=False).max()

data = max_df[max_df['Gene name']=='FOXA1']
x = data['sample']
y = data['tpm']
s = samples_by_resp
g = sns.barplot(x=x,y=y,data=data,order=s,color='grey')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title('FOXA1',size=20)
# Out:
# Text(0.5, 1.0, 'FOXA1')

# %%
max_df = df[['sample','Gene name','tpm']].groupby(['sample','Gene name'],as_index=False).max()
tf = 'SOX5'
data = max_df[max_df['Gene name']==tf]
x = data['sample']
y = data['tpm']
s = samples_by_resp
g = sns.barplot(x=x,y=y,data=data,order=s,color='grey')
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.title(tf,size=20)
# Out:
# Text(0.5, 1.0, 'SOX5')
